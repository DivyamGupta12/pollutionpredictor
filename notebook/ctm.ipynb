# %% [markdown]
# air station - 20.930079,85.172347
#
# coal field - 20.960518,85.168798
#
# gram of pm2.5 produced/ hr = 0.084
#
# ug/hr = 84,474
#
# coord of air station - 0,0
#
# field - 3,365.77, -392.42

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import xarray as xr
import torch

# %%
ds = xr.open_dataset('/content/adaptor.mars.internal-1719349482.2961886-7135-12-89d0a2f3-9667-43f2-a048-5ec13c635a1f.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 1, latitude: 1, time: 24)
# Coordinates:
#   * longitude  (longitude) float32 85.16
#   * latitude   (latitude) float32 20.93
#   * time       (time) datetime64[ns] 2024-06-19 ... 2024-06-19T23:00:00
# Data variables:
#     u10        (time, latitude, longitude) float32 ...
#     v10        (time, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-06-25 21:04:42 GMT by grib_to_netcdf-2.28.1: /opt/ecmw...

# %%
newds=ds.sel(longitude=85.16, latitude=20.93, method='nearest')

# %%
df = newds.to_dataframe()
df['u10']*=3600
df['v10']*=3600
df
# Out:
#                      longitude  latitude           u10          v10
# time
# 2024-06-19 00:00:00  85.160004     20.93   4105.960938  -587.972168
# 2024-06-19 01:00:00  85.160004     20.93   7235.465332   775.440063
# 2024-06-19 02:00:00  85.160004     20.93   8491.284180  2590.308838
# 2024-06-19 03:00:00  85.160004     20.93   9729.509766  2123.131348
# 2024-06-19 04:00:00  85.160004     20.93  11815.458984   797.143311
# 2024-06-19 05:00:00  85.160004     20.93  11798.863281   100.829170
# 2024-06-19 06:00:00  85.160004     20.93  11645.682617   -55.545761
# 2024-06-19 07:00:00  85.160004     20.93  11678.541992   603.204895
# 2024-06-19 08:00:00  85.160004     20.93  11153.612305  1974.408203
# 2024-06-19 09:00:00  85.160004     20.93  11813.135742  2925.458008
# 2024-06-19 10:00:00  85.160004     20.93  10943.838867   342.069641
# 2024-06-19 11:00:00  85.160004     20.93   8408.635742  2087.376709
# 2024-06-19 12:00:00  85.160004     20.93   4534.635254  3156.959473
# 2024-06-19 13:00:00  85.160004     20.93   2662.773926  5510.654785
# 2024-06-19 14:00:00  85.160004     20.93    939.612549  6282.791016
# 2024-06-19 15:00:00  85.160004     20.93   1474.003418  6760.124512
# 2024-06-19 16:00:00  85.160004     20.93   2651.488525  6079.670410
# 2024-06-19 17:00:00  85.160004     20.93   3560.450684  3920.470215
# 2024-06-19 18:00:00  85.160004     20.93   3813.539551  3582.956299
# 2024-06-19 19:00:00  85.160004     20.93   2724.012939  3939.391357
# 2024-06-19 20:00:00  85.160004     20.93   3394.324951  3698.011719
# 2024-06-19 21:00:00  85.160004     20.93   5248.925781  2633.437012
# 2024-06-19 22:00:00  85.160004     20.93   5215.734375    40.449429
# 2024-06-19 23:00:00  85.160004     20.93   5013.263184 -2357.069580

# %%
dataf = pd.read_excel('/content/site_140820240625195348.xlsx')

# %%
dataf['PM2.5'].interpolate(method='linear', inplace=True)
dataf
# Out:
#            From Date           To Date   PM2.5
# 0   19-06-2024 00:00  19-06-2024 00:30  52.590
# 1   19-06-2024 00:30  19-06-2024 01:00  56.920
# 2   19-06-2024 01:00  19-06-2024 01:30  45.970
# 3   19-06-2024 01:30  19-06-2024 02:00  30.150
# 4   19-06-2024 02:00  19-06-2024 02:30  26.830
# 5   19-06-2024 02:30  19-06-2024 03:00  17.010
# 6   19-06-2024 03:00  19-06-2024 03:30  10.500
# 7   19-06-2024 03:30  19-06-2024 04:00  15.970
# 8   19-06-2024 04:00  19-06-2024 04:30  19.370
# 9   19-06-2024 04:30  19-06-2024 05:00  34.660
# 10  19-06-2024 05:00  19-06-2024 05:30  34.980
# 11  19-06-2024 05:30  19-06-2024 06:00  87.570
# 12  19-06-2024 06:00  19-06-2024 06:30  89.680
# 13  19-06-2024 06:30  19-06-2024 07:00  91.410
# 14  19-06-2024 07:00  19-06-2024 07:30  81.100
# 15  19-06-2024 07:30  19-06-2024 08:00  65.530
# 16  19-06-2024 08:00  19-06-2024 08:30  61.170
# 17  19-06-2024 08:30  19-06-2024 09:00  59.930
# 18  19-06-2024 09:00  19-06-2024 09:30  61.860
# 19  19-06-2024 09:30  19-06-2024 10:00  51.980
# 20  19-06-2024 10:00  19-06-2024 10:30  42.100
# 21  19-06-2024 10:30  19-06-2024 11:00  32.220
# 22  19-06-2024 11:00  19-06-2024 11:30  24.660
# 23  19-06-2024 11:30  19-06-2024 12:00  19.420
# 24  19-06-2024 12:00  19-06-2024 12:30  22.840
# 25  19-06-2024 12:30  19-06-2024 13:00  33.750
# 26  19-06-2024 13:00  19-06-2024 13:30  32.150
# 27  19-06-2024 13:30  19-06-2024 14:00  38.280
# 28  19-06-2024 14:00  19-06-2024 14:30  26.610
# 29  19-06-2024 14:30  19-06-2024 15:00  38.790
# 30  19-06-2024 15:00  19-06-2024 15:30  43.340
# 31  19-06-2024 15:30  19-06-2024 16:00  47.480
# 32  19-06-2024 16:00  19-06-2024 16:30  48.970
# 33  19-06-2024 16:30  19-06-2024 17:00  63.780
# 34  19-06-2024 17:00  19-06-2024 17:30  64.740
# 35  19-06-2024 17:30  19-06-2024 18:00  46.350
# 36  19-06-2024 18:00  19-06-2024 18:30  48.340
# 37  19-06-2024 18:30  19-06-2024 19:00  30.700
# 38  19-06-2024 19:00  19-06-2024 19:30  22.640
# 39  19-06-2024 19:30  19-06-2024 20:00   9.730
# 40  19-06-2024 20:00  19-06-2024 20:30   9.960
# 41  19-06-2024 20:30  19-06-2024 21:00  31.200
# 42  19-06-2024 21:00  19-06-2024 21:30  50.600
# 43  19-06-2024 21:30  19-06-2024 22:00  46.838
# 44  19-06-2024 22:00  19-06-2024 22:30  43.076
# 45  19-06-2024 22:30  19-06-2024 23:00  39.314
# 46  19-06-2024 23:00  19-06-2024 23:30  35.552
# 47  19-06-2024 23:30  20-06-2024 00:00  31.790
# 48  20-06-2024 00:00  20-06-2024 00:00  31.790

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(3, 20)
        self.fc2 = nn.Linear(20, 20)
        self.fc3 = nn.Linear(20, 1)

    def forward(self, x, y, t):
        inputs = torch.cat([x, y, t], dim=1)
        out = torch.relu(self.fc1(inputs))
        out = torch.relu(self.fc2(out))
        out = self.fc3(out)
        return out

# Define the PDE loss function
def pde_loss(model, x, y, t, u_x, u_y):
    x.requires_grad = True
    y.requires_grad = True
    t.requires_grad = True
    c = model(x, y, t)

    # Compute partial derivatives
    c_t = torch.autograd.grad(c, t, grad_outputs=torch.ones_like(c), create_graph=True)[0]
    c_x = torch.autograd.grad(c, x, grad_outputs=torch.ones_like(c), create_graph=True)[0]
    c_y = torch.autograd.grad(c, y, grad_outputs=torch.ones_like(c), create_graph=True)[0]

    c_xx = torch.autograd.grad(c_x, x, grad_outputs=torch.ones_like(c_x), create_graph=True)[0]
    c_yy = torch.autograd.grad(c_y, y, grad_outputs=torch.ones_like(c_y), create_graph=True)[0]

    K_xx, K_yy = 1, 1  # values for diffusion coefficients
    diffusion = K_xx * c_xx + K_yy * c_yy
    E = torch.zeros_like(c)
    E[(x <= -380) & (x >= -400) & (y >= 3300) & (y <= 3400)] = 84.45
    S = torch.full_like(c, 5)
    residual = c_t + u_x * c_x + u_y * c_y - diffusion + S - E
    loss = torch.mean(residual ** 2)

    t_boundary = torch.zeros_like(t).requires_grad_(True)
    i = model(x, y, t_boundary)
    loss2 = torch.mean((torch.squeeze(i) - 52.59) ** 2)
    return loss + loss2

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = Net().to(device)
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Create a grid of points (x, y, t) for training
x = torch.linspace(0, -400, 50)
y = torch.linspace(0, 3500, 50)
t = torch.linspace(0, 23, 24)
x, y, t = torch.meshgrid(x, y, t)
x = x.flatten().unsqueeze(1).to(device)
y = y.flatten().unsqueeze(1).to(device)
t = t.flatten().unsqueeze(1).to(device)

u_x = torch.tensor(df['u10'].values).to(device)
u_y = torch.tensor(df['v10'].values).to(device)

# Repeat u_x and u_y values to match the dimensions of (x, y, t)
u_x = u_x.unsqueeze(1).unsqueeze(1).repeat(1, 50, 50).flatten().unsqueeze(1).to(device)
u_y = u_y.unsqueeze(1).unsqueeze(1).repeat(1, 50, 50).flatten().unsqueeze(1).to(device)

# Combine inputs and velocities into one tensor
data = torch.cat([x, y, t, u_x, u_y], dim=1)

# Training loop
batch_size = 5000
epochs = 1000  # Fewer epochs for quicker testing

for epoch in range(epochs):
    # Shuffle data
    permutation = torch.randperm(data.size(0))
    data = data[permutation]

    for i in range(0, data.size(0), batch_size):
        batch_data = data[i:i + batch_size]
        batch_x, batch_y, batch_t, batch_u_x, batch_u_y = batch_data[:, 0:1], batch_data[:, 1:2], batch_data[:, 2:3], batch_data[:, 3:4], batch_data[:, 4:5]

        optimizer.zero_grad()
        loss = pde_loss(model, batch_x, batch_y, batch_t, batch_u_x, batch_u_y)
        loss.backward()
        optimizer.step()

    if epoch % 100 == 0:
        print(f'Epoch {epoch}: Loss = {loss.item()}')

# Evaluate the model at x = 0 for varying t
x_eval = torch.zeros(100, 1).to(device)  # x = 0
y_eval = torch.zeros(100, 1).to(device)  # y = 0
t_eval = torch.linspace(0, 24, 100).view(-1, 1).to(device)  # t from 0 to 23 hours

# Make predictions
with torch.no_grad():
    q_pred = model(x_eval, y_eval, t_eval).cpu().numpy()

t_ground_truth = torch.linspace(0, 24, len(dataf['PM2.5'])).view(-1, 1).cpu().numpy()
plt.plot(t_eval.cpu().numpy(), q_pred, label='Concentration at (0,0)')

plt.plot(t_ground_truth,dataf['PM2.5'].values, label='ground truth',color = 'red')

plt.xlabel('Time (hours)')
plt.ylabel('Concentration')
plt.title('Concentration Variation at Point (0,0)')
plt.legend()
plt.show()
# Out:
# Epoch 0: Loss = 38135.1796875
# Epoch 100: Loss = 1992.7081298828125
# Epoch 200: Loss = 1376.4609375
# Epoch 300: Loss = 250.6407470703125
# Epoch 400: Loss = 89.17274475097656
# Epoch 500: Loss = 68.97905731201172
# Epoch 600: Loss = 26.70794677734375
# Epoch 700: Loss = 19.142688751220703
# Epoch 800: Loss = 8.802535057067871
# Epoch 900: Loss = 10.094963073730469
